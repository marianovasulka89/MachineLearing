# %%
"""
normalizar lso datos
(x_i-media)/varianza_todos_los_datos

(x_i-min)/(max-min)
este es suceotible a outliers

{vamos a tener que separar entre testing, validation, y training sets

entrenamos con trainiing, y validamos con validation, si con dos o tres training sets , y validation test andan(reentrenar,y correr), los juntamos, reentrenamos, y usamos test set

cross validation, es otra manera}  todo esto para la eleccon del modelo
"""
